# %% [markdown]
# ### Video Indexer API Samples (Python)

# %% [markdown]
# This notebook provides samples for the following operations in Video Indexer:
#
# (1) Get account details.
# (2) Upload a video from URL.
# (2A) Upload a video from local file.
# (3) Wait for the video to finish indexing.
# (4) Search for video and get insights.
# (5) Use the Widgets API.
#
# Make sure you're logged-in with `az` to authenticate your account.
#
# Copy the `.env.example` file to a new file named `.env`, and update the values with your own account settings.

# %%
# imports
from dotenv import dotenv_values
from pprint import pprint

from VideoIndexerClient.Consts import Consts
from VideoIndexerClient.VideoIndexerClient import VideoIndexerClient

# %% [markdown]
# Define the following parameters based on your account settings, in case they are different or not defined as environment variables:

# %%
config = dotenv_values(".env")

AccountName = config.get('AccountName')
ResourceGroup = config.get('ResourceGroup')
SubscriptionId = config.get('SubscriptionId')

ApiVersion = '2024-01-01'
ApiEndpoint = 'https://api.videoindexer.ai'
AzureResourceManager = 'https://management.azure.com'

# create and validate consts
consts = Consts(ApiVersion, ApiEndpoint, AzureResourceManager, AccountName, ResourceGroup, SubscriptionId)

# %%
# Authenticate

# create Video Indexer Client
client = VideoIndexerClient()

# Get access tokens (arm and Video Indexer account)
client.authenticate_async(consts)

# %% [markdown]
# #### Sample 1 - Get Account Basic Details
# Get account details, not required in most cases.

# %%
client.get_account_async()
# Out:
# [Account Details] Id:9a5f0740-eee6-4f8a-8022-f83961dc2f46, Location: japaneast

# %% [markdown]
# #### Sample 2 - Index a Video from URL
# Upload a video from URL, do not wait for the index operation to complete.
# Define `videoUrl` and `ExcludedAI` first.
# `ExcludedAI` - A list of the AIs you would like to exclude in the format `['Faces', 'Labels', 'Emotions','ObservedPeople']`. Leave empty if you do not want to exclude any AIs. For more details see [here](https://api-portal.videoindexer.ai/api-details#api=Operations&operation=Upload-Video:~:text=AI%20to%20exclude%20when%20indexing%2C%20for%20example%20for%20sensitive%20scenarios.%20Options%20are%3A%20Face/Observed%20peopleEmotions/Labels%7D).

# %%
video_url = 'https://sttestintelligent002.blob.core.windows.net/container-testintelligent-02/Zoom%20%E3%82%A6%E3%82%A7%E3%83%93%E3%83%8A%E3%83%BC%202024-07-18%2019-10-45.mp4?sp=r&st=2024-12-11T09:46:05Z&se=2024-12-11T17:46:05Z&spr=https&sv=2022-11-02&sr=b&sig=E8oSnXvh%2FIadJIWFoeI9vWrvcAnMATq7EGzXxL8hLjY%3D'
video_name = "video_short"
video_description = "first_test"
privacy = 'private'
ExcludedAI = []
video_id = client.upload_url_async(video_name, video_url, ExcludedAI, False)
# Out:
# Video ID zsxqw62q07 was uploaded successfully

# %% [markdown]
# #### Sample 2A - Index a Video From File
# Upload From Local File.
# Define `LocalVideoPath` first.

# %%
LocalVideoPath = 'undefined'
video_name = "Meet_short"
file_video_id = client.file_upload_async(LocalVideoPath, video_name, excluded_ai=ExcludedAI)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 LocalVideoPath = 'C:\\Users\\leggi\\Videos\\Meet_short.mp4'
#       2 video_name = "Meet_short"
# ----> 3 file_video_id = client.file_upload_async(LocalVideoPath, video_name, excluded_ai=ExcludedAI)
#
# File ~/terraform/azure/vr/azure-video-indexer-samples/API-Samples/Python/VideoIndexerClient/VideoIndexerClient.py:122, in VideoIndexerClient.file_upload_async(self, media_path, video_name, excluded_ai, video_description, privacy, partition)
#     119     video_name = get_file_name_no_extension(media_path)
#     121 if not os.path.exists(media_path):
# --> 122     raise Exception(f'Could not find the local file {media_path}')
#     124 self.get_account_async() # if account is not initialized, get it
#     126 url = f'{self.consts.ApiEndpoint}/{self.account["location"]}/Accounts/{self.account["properties"]["accountId"]}/Videos'
#
# Exception: Could not find the local file C:\Users\leggi\Videos\Meet_short.mp4

# %% [markdown]
# #### Sample 3 - Polling on Video Completion Event
# Wait for the video index to finish (Polling method).

# %%
client.wait_for_index_async(video_id)
# Out:
# Checking if video zsxqw62q07 has finished indexing...
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index has completed. Here is the full JSON of the index for video ID zsxqw62q07:
# {'partition': None, 'description': None, 'privacyMode': 'Private', 'state': 'Processed', 'accountId': '9a5f0740-eee6-4f8a-8022-f83961dc2f46', 'id': 'zsxqw62q07', 'name': 'video_short', 'userName': 'Chihiro Kuga', 'created': '2024-12-11T09:46:57.3166667+00:00', 'isOwned': True, 'isEditable': True, 'isBase': True, 'durationInSeconds': 5, 'duration': '0:00:05.290646', 'summarizedInsights': {'name': 'video_short', 'id': 'zsxqw62q07', 'privacyMode': 'Private', 'duration': {'time': '0:00:05.290646', 'seconds': 5.3}, 'thumbnailVideoId': 'zsxqw62q07', 'thumbnailId': '7cad8a68-fab1-4972-a4d6-1544c343e218', 'faces': [{'videoId': 'zsxqw62q07', 'confidence': 0, 'description': None, 'title': None, 'thumbnailId': 'fbcc332e-6e3f-4894-9225-10e669a535a4', 'seenDuration': 5.2, 'seenDurationRatio': 0.9829, 'id': 1000, 'name': 'Unknown #1', 'appearances': [{'startTime': '0:00:00.0741667', 'endTime': '0:00:05.290646', 'startSeconds': 0.1, 'endSeconds': 5.3}]}], 'keywords': [], 'sentiments': [{'sentimentKey': 'Neutral', 'seenDurationRatio': 1, 'appearances': [{'startTime': '0:00:00', 'endTime': '0:00:05.290646', 'startSeconds': 0, 'endSeconds': 5.3}]}], 'emotions': [], 'audioEffects': [{'audioEffectKey': 'Silence', 'seenDurationRatio': 0.189, 'seenDuration': 1, 'appearances': [{'confidence': 0.7629, 'startTime': '0:00:00.5', 'endTime': '0:00:01.5', 'startSeconds': 0.5, 'endSeconds': 1.5}]}], 'labels': [{'id': 1, 'name': 'text', 'appearances': [{'confidence': 0.9998, 'startTime': '0:00:00.0741667', 'endTime': '0:00:05.2055667', 'startSeconds': 0.1, 'endSeconds': 5.2}]}, {'id': 2, 'name': 'electronics', 'appearances': [{'confidence': 0.9948, 'startTime': '0:00:00.0741667', 'endTime': '0:00:05.2055667', 'startSeconds': 0.1, 'endSeconds': 5.2}]}, {'id': 3, 'name': 'software', 'appearances': [{'confidence': 0.9524, 'startTime': '0:00:03.1563333', 'endTime': '0:00:05.2055667', 'startSeconds': 3.2, 'endSeconds': 5.2}]}], 'framePatterns': [], 'brands': [{'referenceId': 'Gartner', 'referenceUrl': 'http://en.wikipedia.org/wiki/Gartner', 'confidence': 1, 'description': 'Gartner, Inc. is an American research and advisory firm providing information technology related insight headquartered in Stamford, Connecticut, United States. It was known as Gartner Group, Inc until 2001.', 'seenDuration': 0, 'id': 1, 'name': 'Gartner', 'appearances': [{'startTime': '0:00:00.0741667', 'endTime': '0:00:00.0908', 'startSeconds': 0.1, 'endSeconds': 0.1}]}], 'namedLocations': [{'referenceId': None, 'referenceUrl': None, 'confidence': 1, 'description': None, 'seenDuration': 4.4, 'id': 1, 'name': 'Tokyo', 'appearances': [{'startTime': '0:00:00.56', 'endTime': '0:00:05.04', 'startSeconds': 0.6, 'endSeconds': 5}]}], 'namedPeople': [], 'statistics': {'correspondenceCount': 0, 'speakerTalkToListenRatio': {'1': 1}, 'speakerLongestMonolog': {'1': 4}, 'speakerNumberOfFragments': {'1': 1}, 'speakerWordCount': {'1': 12}}, 'topics': [{'referenceUrl': None, 'iptcName': 'lifestyle and leisure/leisure/game/video game', 'iabName': 'Hobbies & Interests', 'confidence': 0.5764, 'id': 1, 'name': 'Games and Gaming/Games', 'appearances': [{'startTime': '0:00:00.56', 'endTime': '0:00:05.04', 'startSeconds': 0.6, 'endSeconds': 5}]}]}, 'videos': [{'accountId': '9a5f0740-eee6-4f8a-8022-f83961dc2f46', 'id': 'zsxqw62q07', 'state': 'Processed', 'moderationState': 'OK', 'reviewState': 'None', 'privacyMode': 'Private', 'processingProgress': '100%', 'failureMessage': '', 'externalId': None, 'externalUrl': None, 'metadata': None, 'insights': {'version': '1.0.0.0', 'duration': '0:00:05.290646', 'sourceLanguage': 'en-US', 'sourceLanguages': ['en-US'], 'language': 'en-US', 'languages': ['en-US'], 'transcript': [{'id': 1, 'text': "If I'm not doing a lot, even when you don't know Tokyo.", 'confidence': 0.3418, 'speakerId': 1, 'language': 'en-US', 'instances': [{'adjustedStart': '0:00:00.56', 'adjustedEnd': '0:00:05.04', 'start': '0:00:00.56', 'end': '0:00:05.04'}]}], 'ocr': [{'id': 1, 'text': '3%', 'confidence': 0.9 ...

# %% [markdown]
# #### Sample 4 - Get the Video insights
# Get the video insights.

# %%
insights = client.get_video_async(video_id)
pprint(insights)
# Out:
# Searching videos in account 9a5f0740-eee6-4f8a-8022-f83961dc2f46 for video ID zsxqw62q07.
# Here are the search results:
# {'partition': None, 'description': None, 'privacyMode': 'Private', 'state': 'Processed', 'accountId': '9a5f0740-eee6-4f8a-8022-f83961dc2f46', 'id': 'zsxqw62q07', 'name': 'video_short', 'userName': 'Chihiro Kuga', 'created': '2024-12-11T09:46:57.3166667+00:00', 'isOwned': True, 'isEditable': True, 'isBase': True, 'durationInSeconds': 5, 'duration': '0:00:05.290646', 'summarizedInsights': {'name': 'video_short', 'id': 'zsxqw62q07', 'privacyMode': 'Private', 'duration': {'time': '0:00:05.290646', 'seconds': 5.3}, 'thumbnailVideoId': 'zsxqw62q07', 'thumbnailId': '7cad8a68-fab1-4972-a4d6-1544c343e218', 'faces': [{'videoId': 'zsxqw62q07', 'confidence': 0, 'description': None, 'title': None, 'thumbnailId': 'fbcc332e-6e3f-4894-9225-10e669a535a4', 'seenDuration': 5.2, 'seenDurationRatio': 0.9829, 'id': 1000, 'name': 'Unknown #1', 'appearances': [{'startTime': '0:00:00.0741667', 'endTime': '0:00:05.290646', 'startSeconds': 0.1, 'endSeconds': 5.3}]}], 'keywords': [], 'sentiments': [{'sentimentKey': 'Neutral', 'seenDurationRatio': 1, 'appearances': [{'startTime': '0:00:00', 'endTime': '0:00:05.290646', 'startSeconds': 0, 'endSeconds': 5.3}]}], 'emotions': [], 'audioEffects': [{'audioEffectKey': 'Silence', 'seenDurationRatio': 0.189, 'seenDuration': 1, 'appearances': [{'confidence': 0.7629, 'startTime': '0:00:00.5', 'endTime': '0:00:01.5', 'startSeconds': 0.5, 'endSeconds': 1.5}]}], 'labels': [{'id': 1, 'name': 'text', 'appearances': [{'confidence': 0.9998, 'startTime': '0:00:00.0741667', 'endTime': '0:00:05.2055667', 'startSeconds': 0.1, 'endSeconds': 5.2}]}, {'id': 2, 'name': 'electronics', 'appearances': [{'confidence': 0.9948, 'startTime': '0:00:00.0741667', 'endTime': '0:00:05.2055667', 'startSeconds': 0.1, 'endSeconds': 5.2}]}, {'id': 3, 'name': 'software', 'appearances': [{'confidence': 0.9524, 'startTime': '0:00:03.1563333', 'endTime': '0:00:05.2055667', 'startSeconds': 3.2, 'endSeconds': 5.2}]}], 'framePatterns': [], 'brands': [{'referenceId': 'Gartner', 'referenceUrl': 'http://en.wikipedia.org/wiki/Gartner', 'confidence': 1, 'description': 'Gartner, Inc. is an American research and advisory firm providing information technology related insight headquartered in Stamford, Connecticut, United States. It was known as Gartner Group, Inc until 2001.', 'seenDuration': 0, 'id': 1, 'name': 'Gartner', 'appearances': [{'startTime': '0:00:00.0741667', 'endTime': '0:00:00.0908', 'startSeconds': 0.1, 'endSeconds': 0.1}]}], 'namedLocations': [{'referenceId': None, 'referenceUrl': None, 'confidence': 1, 'description': None, 'seenDuration': 4.4, 'id': 1, 'name': 'Tokyo', 'appearances': [{'startTime': '0:00:00.56', 'endTime': '0:00:05.04', 'startSeconds': 0.6, 'endSeconds': 5}]}], 'namedPeople': [], 'statistics': {'correspondenceCount': 0, 'speakerTalkToListenRatio': {'1': 1}, 'speakerLongestMonolog': {'1': 4}, 'speakerNumberOfFragments': {'1': 1}, 'speakerWordCount': {'1': 12}}, 'topics': [{'referenceUrl': None, 'iptcName': 'lifestyle and leisure/leisure/game/video game', 'iabName': 'Hobbies & Interests', 'confidence': 0.5764, 'id': 1, 'name': 'Games and Gaming/Games', 'appearances': [{'startTime': '0:00:00.56', 'endTime': '0:00:05.04', 'startSeconds': 0.6, 'endSeconds': 5}]}]}, 'videos': [{'accountId': '9a5f0740-eee6-4f8a-8022-f83961dc2f46', 'id': 'zsxqw62q07', 'state': 'Processed', 'moderationState': 'OK', 'reviewState': 'None', 'privacyMode': 'Private', 'processingProgress': '100%', 'failureMessage': '', 'externalId': None, 'externalUrl': None, 'metadata': None, 'insights': {'version': '1.0.0.0', 'duration': '0:00:05.290646', 'sourceLanguage': 'en-US', 'sourceLanguages': ['en-US'], 'language': 'en-US', 'languages': ['en-US'], 'transcript': [{'id': 1, 'text': "If I'm not doing a lot, even when you don't know Tokyo.", 'confidence': 0.3418, 'speakerId': 1, 'language': 'en-US', 'instances': [{'adjustedStart': '0:00:00.56', 'adjustedEnd': '0:00:05.04', 'start': '0:00:00.56', 'end': '0:00:05.04'}]}], 'ocr': [{'id': 1, 'text': '3%', 'confidence': 0.9 ...
# {'accountId': '9a5f0740-eee6-4f8a-8022-f83961dc2f46',
#  'created': '2024-12-11T09:46:57.3166667+00:00',
#  'description': None,
#  'duration': '0:00:05.290646',
#  'durationInSeconds': 5,
#  'id': 'zsxqw62q07',
#  'isBase': True,
#  'isEditable': True,
#  'isOwned': True,
#  'name': 'video_short',
#  'partition': None,
#  'privacyMode': 'Private',
#  'state': 'Processed',
#  'summarizedInsights': {'audioEffects': [{'appearances': [{'confidence': 0.7629,
#                                                            'endSeconds': 1.5,
#                                                            'endTime': '0:00:01.5',
#                                                            'startSeconds': 0.5,
#                                                            'startTime': '0:00:00.5'}],
#                                           'audioEffectKey': 'Silence',
#                                           'seenDuration': 1,
#                                           'seenDurationRatio': 0.189}],
#                         'brands': [{'appearances': [{'endSeconds': 0.1,
#                                                      'endTime': '0:00:00.0908',
#                                                      'startSeconds': 0.1,
#                                                      'startTime': '0:00:00.0741667'}],
#                                     'confidence': 1,
#                                     'description': 'Gartner, Inc. is an '
#                                                    'American research and '
#                                                    'advisory firm providing '
#                                                    'information technology '
#                                                    'related insight '
#                                                    'headquartered in Stamford, '
#                                                    'Connecticut, United '
#                                                    'States. It was known as '
#                                                    'Gartner Group, Inc until '
#                                                    '2001.',
#                                     'id': 1,
#                                     'name': 'Gartner',
#                                     'referenceId': 'Gartner',
#                                     'referenceUrl': 'http://en.wikipedia.org/wiki/Gartner',
#                                     'seenDuration': 0}],
#                         'duration': {'seconds': 5.3, 'time': '0:00:05.290646'},
#                         'emotions': [],
#                         'faces': [{'appearances': [{'endSeconds': 5.3,
#                                                     'endTime': '0:00:05.290646',
#                                                     'startSeconds': 0.1,
#                                                     'startTime': '0:00:00.0741667'}],
#                                    'confidence': 0,
#                                    'description': None,
#                                    'id': 1000,
#                                    'name': 'Unknown #1',
#                                    'seenDuration': 5.2,
#                                    'seenDurationRatio': 0.9829,
#                                    'thumbnailId': 'fbcc332e-6e3f-4894-9225-10e669a535a4',
#                                    'title': None,
#                                    'videoId': 'zsxqw62q07'}],
#                         'framePatterns': [],
#                         'id': 'zsxqw62q07',
#                         'keywords': [],
#                         'labels': [{'appearances': [{'confidence': 0.9998,
#                                                      'endSeconds': 5.2,
#                                                      'endTime': '0:00:05.2055667',
#                                                      'startSeconds': 0.1,
#                                                      'startTime': '0:00:00.0741667'}],
#                                     'id': 1,
#                                     'name': 'text'},
#                                    {'appearances': [{'confidence': 0.9948,
#                                                      'endSeconds': 5.2,
#                                                      'endTime': '0:00:05.2055667',
#                                                      'startSeconds': 0.1,
#                                                      'startTime': '0:00:00.0741667'}],
#                                     'id': 2,
#                                     'name': 'electronics'},
#                                    {'appearances': [{'confidence': 0.9524,
#                                                      'endSeconds': 5.2,
#                                                      'endTime': '0:00:05.2055667',
#                                                      'startSeconds': 3.2,
#                                                      'startTime': '0:00:03.1563333'}],
#                                     'id': 3,
#                                     'name': 'software'}],
#                         'name': 'video_short',
#                         'namedLocations': [{'appearances': [{'endSeconds': 5,
#                                                              'endTime': '0:00:05.04',
#                                                              'startSeconds': 0.6,
#                                                              'startTime': '0:00:00.56'}],
#                                             'confidence': 1,
#                                             'description': None,
#                                             'id': 1,
#                                             'name': 'Tokyo',
#                                             'referenceId': None,
#                                             'referenceUrl': None,
#                                             'seenDuration': 4.4}],
#                         'namedPeople': [],
#                         'privacyMode': 'Private',
#                         'sentiments': [{'appearances': [{'endSeconds': 5.3,
#                                                          'endTime': '0:00:05.290646',
#                                                          'startSeconds': 0,
#                                                          'startTime': '0:00:00'}],
#                                         'seenDurationRatio': 1,
#                                         'sentimentKey': 'Neutral'}],
#                         'statistics': {'correspondenceCount': 0,
#                                        'speakerLongestMonolog': {'1': 4},
#                                        'speakerNumberOfFragments': {'1': 1},
#                                        'speakerTalkToListenRatio': {'1': 1},
#                                        'speakerWordCount': {'1': 12}},
#                         'thumbnailId': '7cad8a68-fab1-4972-a4d6-1544c343e218',
#                         'thumbnailVideoId': 'zsxqw62q07',
#                         'topics': [{'appearances': [{'endSeconds': 5,
#                                                      'endTime': '0:00:05.04',
#                                                      'startSeconds': 0.6,
#                                                      'startTime': '0:00:00.56'}],
#                                     'confidence': 0.5764,
#                                     'iabName': 'Hobbies & Interests',
#                                     'id': 1,
#                                     'iptcName': 'lifestyle and '
#                                                 'leisure/leisure/game/video '
#                                                 'game',
#                                     'name': 'Games and Gaming/Games',
#                                     'referenceUrl': None}]},
#  'userName': 'Chihiro Kuga',
#  'videos': [{'accountId': '9a5f0740-eee6-4f8a-8022-f83961dc2f46',
#              'detectSourceLanguage': False,
#              'excludedAIs': [],
#              'externalId': None,
#              'externalUrl': None,
#              'failureMessage': '',
#              'height': 964,
#              'id': 'zsxqw62q07',
#              'indexingPreset': 'Default',
#              'insights': {'audioEffects': [{'id': 0,
#                                             'instances': [{'adjustedEnd': '0:00:01.5',
#                                                            'adjustedStart': '0:00:00.5',
#                                                            'confidence': 0.7629,
#                                                            'end': '0:00:01.5',
#                                                            'start': '0:00:00.5'}],
#                                             'type': 'Silence'}],
#                           'blocks': [{'id': 0,
#                                       'instances': [{'adjustedEnd': '0:00:05.290646',
#                                                      'adjustedStart': '0:00:00',
#                                                      'end': '0:00:05.290646',
#                                                      'start': '0:00:00'}]}],
#                           'brands': [{'confidence': 1,
#                                       'description': 'Gartner, Inc. is an '
#                                                      'American research and '
#                                                      'advisory firm providing '
#                                                      'information technology '
#                                                      'related insight '
#                                                      'headquartered in '
#                                                      'Stamford, Connecticut, '
#                                                      'United States. It was '
#                                                      'known as Gartner Group, '
#                                                      'Inc until 2001.',
#                                       'id': 1,
#                                       'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                      'adjustedStart': '0:00:00.0741667',
#                                                      'brandType': 'Ocr',
#                                                      'end': '0:00:00.0908',
#                                                      'instanceSource': 'Ocr',
#                                                      'start': '0:00:00.0741667'}],
#                                       'isCustom': False,
#                                       'name': 'Gartner',
#                                       'referenceId': 'Gartner',
#                                       'referenceType': 'Wiki',
#                                       'referenceUrl': 'http://en.wikipedia.org/wiki/Gartner',
#                                       'tags': []}],
#                           'detectedObjects': [{'displayName': 'laptop',
#                                                'id': 1,
#                                                'instances': [{'adjustedEnd': '0:00:01.933321',
#                                                               'adjustedStart': '0:00:00',
#                                                               'confidence': 0.751,
#                                                               'end': '0:00:01.933321',
#                                                               'start': '0:00:00'}],
#                                                'thumbnailId': '5b958efd-5c93-415a-a252-7c496ba4b701',
#                                                'type': 'Laptop',
#                                                'wikiDataId': 'Q3962'}],
#                           'duration': '0:00:05.290646',
#                           'faces': [{'confidence': 0,
#                                      'description': None,
#                                      'highQuality': True,
#                                      'id': 1000,
#                                      'imageUrl': None,
#                                      'instances': [{'adjustedEnd': '0:00:05.290646',
#                                                     'adjustedStart': '0:00:00.0741667',
#                                                     'end': '0:00:05.290646',
#                                                     'start': '0:00:00.0741667',
#                                                     'thumbnailsIds': ['788b59e8-138b-462b-aa9a-e6678071c48b']}],
#                                      'name': 'Unknown #1',
#                                      'thumbnailId': 'fbcc332e-6e3f-4894-9225-10e669a535a4',
#                                      'thumbnails': [{'fileName': 'FaceInstanceThumbnail_788b59e8-138b-462b-aa9a-e6678071c48b.jpg',
#                                                      'id': '788b59e8-138b-462b-aa9a-e6678071c48b',
#                                                      'instances': [{'adjustedEnd': '0:00:02.8230666',
#                                                                     'adjustedStart': '0:00:02.8064',
#                                                                     'end': '0:00:02.8230666',
#                                                                     'start': '0:00:02.8064'}]}],
#                                      'title': None}],
#                           'labels': [{'id': 1,
#                                       'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                      'adjustedStart': '0:00:00.0741667',
#                                                      'confidence': 0.9998,
#                                                      'end': '0:00:00.0908',
#                                                      'start': '0:00:00.0741667'},
#                                                     {'adjustedEnd': '0:00:02.0401',
#                                                      'adjustedStart': '0:00:01.1906',
#                                                      'confidence': 0.9999,
#                                                      'end': '0:00:02.0401',
#                                                      'start': '0:00:01.1906'},
#                                                     {'adjustedEnd': '0:00:03.2563667',
#                                                      'adjustedStart': '0:00:03.1563333',
#                                                      'confidence': 0.9998,
#                                                      'end': '0:00:03.2563667',
#                                                      'start': '0:00:03.1563333'},
#                                                     {'adjustedEnd': '0:00:05.2055667',
#                                                      'adjustedStart': '0:00:04.3225333',
#                                                      'confidence': 0.9998,
#                                                      'end': '0:00:05.2055667',
#                                                      'start': '0:00:04.3225333'}],
#                                       'language': 'en-US',
#                                       'name': 'text',
#                                       'referenceId': 'communication/writing/text'},
#                                      {'id': 2,
#                                       'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                      'adjustedStart': '0:00:00.0741667',
#                                                      'confidence': 0.9981,
#                                                      'end': '0:00:00.0908',
#                                                      'start': '0:00:00.0741667'},
#                                                     {'adjustedEnd': '0:00:02.0401',
#                                                      'adjustedStart': '0:00:01.1906',
#                                                      'confidence': 0.9975,
#                                                      'end': '0:00:02.0401',
#                                                      'start': '0:00:01.1906'},
#                                                     {'adjustedEnd': '0:00:03.2563667',
#                                                      'adjustedStart': '0:00:03.1563333',
#                                                      'confidence': 0.9949,
#                                                      'end': '0:00:03.2563667',
#                                                      'start': '0:00:03.1563333'},
#                                                     {'adjustedEnd': '0:00:05.2055667',
#                                                      'adjustedStart': '0:00:04.3225333',
#                                                      'confidence': 0.9948,
#                                                      'end': '0:00:05.2055667',
#                                                      'start': '0:00:04.3225333'}],
#                                       'language': 'en-US',
#                                       'name': 'electronics'},
#                                      {'id': 3,
#                                       'instances': [{'adjustedEnd': '0:00:03.2563667',
#                                                      'adjustedStart': '0:00:03.1563333',
#                                                      'confidence': 0.952,
#                                                      'end': '0:00:03.2563667',
#                                                      'start': '0:00:03.1563333'},
#                                                     {'adjustedEnd': '0:00:05.2055667',
#                                                      'adjustedStart': '0:00:04.3225333',
#                                                      'confidence': 0.9524,
#                                                      'end': '0:00:05.2055667',
#                                                      'start': '0:00:04.3225333'}],
#                                       'language': 'en-US',
#                                       'name': 'software'}],
#                           'language': 'en-US',
#                           'languages': ['en-US'],
#                           'namedLocations': [{'confidence': 1,
#                                               'description': None,
#                                               'id': 1,
#                                               'instances': [{'adjustedEnd': '0:00:05.04',
#                                                              'adjustedStart': '0:00:00.56',
#                                                              'end': '0:00:05.04',
#                                                              'instanceSource': 'Transcript',
#                                                              'start': '0:00:00.56'}],
#                                               'isCustom': False,
#                                               'name': 'Tokyo',
#                                               'referenceId': None,
#                                               'referenceUrl': None,
#                                               'tags': []}],
#                           'ocr': [{'angle': 2,
#                                    'confidence': 0.995,
#                                    'height': 20,
#                                    'id': 1,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'en-US',
#                                    'left': 673,
#                                    'text': '3%',
#                                    'top': 434,
#                                    'width': 35},
#                                   {'angle': 3,
#                                    'confidence': 0.994,
#                                    'height': 43,
#                                    'id': 2,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'en-US',
#                                    'left': 425,
#                                    'text': '97%',
#                                    'top': 467,
#                                    'width': 88},
#                                   {'angle': 0,
#                                    'confidence': 0.995,
#                                    'height': 14,
#                                    'id': 3,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'en-US',
#                                    'left': 806,
#                                    'text': '13%',
#                                    'top': 549,
#                                    'width': 39},
#                                   {'angle': 2,
#                                    'confidence': 0.996,
#                                    'height': 16,
#                                    'id': 4,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'en-US',
#                                    'left': 442,
#                                    'text': '33%',
#                                    'top': 612,
#                                    'width': 36},
#                                   {'angle': 0,
#                                    'confidence': 0.997,
#                                    'height': 14,
#                                    'id': 5,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'en-US',
#                                    'left': 795,
#                                    'text': '23%',
#                                    'top': 826,
#                                    'width': 36},
#                                   {'angle': 3,
#                                    'confidence': 0.997,
#                                    'height': 14,
#                                    'id': 6,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'en-US',
#                                    'left': 524,
#                                    'text': '12%',
#                                    'top': 855,
#                                    'width': 34},
#                                   {'angle': 0,
#                                    'confidence': 0.992,
#                                    'height': 16,
#                                    'id': 7,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 581,
#                                    'text': '前田 達志',
#                                    'top': 126,
#                                    'width': 66},
#                                   {'angle': 0,
#                                    'confidence': 0.9959,
#                                    'height': 23,
#                                    'id': 8,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 155,
#                                    'text': 'データに関わる日本の現状とは?',
#                                    'top': 332,
#                                    'width': 270},
#                                   {'angle': 0,
#                                    'confidence': 0.9957,
#                                    'height': 33,
#                                    'id': 9,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 153,
#                                    'text': '97%の日本企業はデータ活用で全社的に十分な成果を得ていない',
#                                    'top': 369,
#                                    'width': 865},
#                                   {'angle': 0,
#                                    'confidence': 0.9969,
#                                    'height': 24,
#                                    'id': 10,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 673,
#                                    'text': '全社的に十分な成果を得ている',
#                                    'top': 457,
#                                    'width': 276},
#                                   {'angle': 0,
#                                    'confidence': 0.9969,
#                                    'height': 19,
#                                    'id': 11,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 807,
#                                    'text': '全社的にある程度の成果を得ている',
#                                    'top': 565,
#                                    'width': 236},
#                                   {'angle': 0,
#                                    'confidence': 0.9976,
#                                    'height': 19,
#                                    'id': 12,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 290,
#                                    'text': 'わからない/したことがない',
#                                    'top': 627,
#                                    'width': 189},
#                                   {'angle': 0,
#                                    'confidence': 0.995,
#                                    'height': 18,
#                                    'id': 13,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 850,
#                                    'text': '一部で十分な成果を得ている',
#                                    'top': 677,
#                                    'width': 195},
#                                   {'angle': 0,
#                                    'confidence': 0.9881,
#                                    'height': 16,
#                                    'id': 14,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
#                                                   'start': '0:00:01.1906'},
#                                                  {'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 326,
#                                    'text': '成果の評価は時期尚早·',
#                                    'top': 785,
#                                    'width': 164},
#                                   {'angle': 0,
#                                    'confidence': 0.9973,
#                                    'height': 17,
#                                    'id': 15,
#                                    'instances': [{'adjustedEnd': '0:00:00.0908',
#                                                   'adjustedStart': '0:00:00.0741667',
#                                                   'end': '0:00:00.0908',
#                                                   'start': '0:00:00.0741667'},
#                                                  {'adjustedEnd': '0:00:02.0401',
#                                                   'adjustedStart': '0:00:01.1906',
#                                                   'end': '0:00:02.0401',
# ...
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'en-US',
#                                    'left': 22,
#                                    'text': 'Workplace',
#                                    'top': 40,
#                                    'width': 117},
#                                   {'angle': 0,
#                                    'confidence': 0.995,
#                                    'height': 22,
#                                    'id': 24,
#                                    'instances': [{'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 282,
#                                    'text': '前田 達志 さんの画面',
#                                    'top': 34,
#                                    'width': 177},
#                                   {'angle': 1,
#                                    'confidence': 0.9974,
#                                    'height': 22,
#                                    'id': 25,
#                                    'instances': [{'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 817,
#                                    'text': 'サインイン',
#                                    'top': 31,
#                                    'width': 79},
#                                   {'angle': 0,
#                                    'confidence': 0.9823,
#                                    'height': 19,
#                                    'id': 26,
#                                    'instances': [{'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 20,
#                                    'text': 'オーディオ設定 へ',
#                                    'top': 915,
#                                    'width': 147},
#                                   {'angle': -1,
#                                    'confidence': 0.9835,
#                                    'height': 19,
#                                    'id': 27,
#                                    'instances': [{'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 502,
#                                    'text': 'チャット',
#                                    'top': 936,
#                                    'width': 57},
#                                   {'angle': 2,
#                                    'confidence': 0.9945,
#                                    'height': 19,
#                                    'id': 28,
#                                    'instances': [{'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'ja-JP',
#                                    'left': 619,
#                                    'text': 'リアクション',
#                                    'top': 934,
#                                    'width': 82},
#                                   {'angle': 0,
#                                    'confidence': 0.992,
#                                    'height': 17,
#                                    'id': 29,
#                                    'instances': [{'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'en-US',
#                                    'left': 891,
#                                    'text': 'Q&A',
#                                    'top': 937,
#                                    'width': 42},
#                                   {'angle': 0,
#                                    'confidence': 0.996,
#                                    'height': 16,
#                                    'id': 30,
#                                    'instances': [{'adjustedEnd': '0:00:03.2563667',
#                                                   'adjustedStart': '0:00:03.1563333',
#                                                   'end': '0:00:03.2563667',
#                                                   'start': '0:00:03.1563333'},
#                                                  {'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'zh-Hans',
#                                    'left': 1301,
#                                    'text': '退出',
#                                    'top': 937,
#                                    'width': 38},
#                                   {'angle': -1,
#                                    'confidence': 0.925,
#                                    'height': 18,
#                                    'id': 31,
#                                    'instances': [{'adjustedEnd': '0:00:05.2055667',
#                                                   'adjustedStart': '0:00:04.3225333',
#                                                   'end': '0:00:05.2055667',
#                                                   'start': '0:00:04.3225333'}],
#                                    'language': 'zh-Hans',
#                                    'left': 765,
#                                    'text': '举手',
#                                    'top': 935,
#                                    'width': 41}],
#                           'scenes': [{'id': 1,
#                                       'instances': [{'adjustedEnd': '0:00:05.2812667',
#                                                      'adjustedStart': '0:00:00.0741667',
#                                                      'end': '0:00:05.2812667',
#                                                      'start': '0:00:00.0741667'}]}],
#                           'sentiments': [{'averageScore': 0.5,
#                                           'id': 1,
#                                           'instances': [{'adjustedEnd': '0:00:05.290646',
#                                                          'adjustedStart': '0:00:00',
#                                                          'end': '0:00:05.290646',
#                                                          'start': '0:00:00'}],
#                                           'sentimentType': 'Neutral'}],
#                           'shots': [{'id': 1,
#                                      'instances': [{'adjustedEnd': '0:00:05.2812667',
#                                                     'adjustedStart': '0:00:00.0741667',
#                                                     'end': '0:00:05.2812667',
#                                                     'start': '0:00:00.0741667'}],
#                                      'keyFrames': [{'id': 1,
#                                                     'instances': [{'adjustedEnd': '0:00:00.2574',
#                                                                    'adjustedStart': '0:00:00.2241',
#                                                                    'end': '0:00:00.2574',
#                                                                    'start': '0:00:00.2241',
#                                                                    'thumbnailId': '0a56f8f9-469e-4a7d-bdb2-bca5d10b0645'}]},
#                                                    {'id': 2,
#                                                     'instances': [{'adjustedEnd': '0:00:00.3740333',
#                                                                    'adjustedStart': '0:00:00.3074',
#                                                                    'end': '0:00:00.3740333',
#                                                                    'start': '0:00:00.3074',
#                                                                    'thumbnailId': 'eac8a5a6-0db8-457e-aee2-5816d94924f4'}]}],
#                                      'tags': ['Wide', 'CenterFace']}],
#                           'sourceLanguage': 'en-US',
#                           'sourceLanguages': ['en-US'],
#                           'speakers': [{'id': 1,
#                                         'instances': [{'adjustedEnd': '0:00:05.04',
#                                                        'adjustedStart': '0:00:00.56',
#                                                        'end': '0:00:05.04',
#                                                        'start': '0:00:00.56'}],
#                                         'name': 'Speaker #1'}],
#                           'statistics': {'correspondenceCount': 0,
#                                          'speakerLongestMonolog': {'1': 4},
#                                          'speakerNumberOfFragments': {'1': 1},
#                                          'speakerTalkToListenRatio': {'1': 1},
#                                          'speakerWordCount': {'1': 12}},
#                           'textualContentModeration': {'bannedWordsCount': 0,
#                                                        'bannedWordsRatio': 0,
#                                                        'id': 0,
#                                                        'instances': []},
#                           'topics': [{'confidence': 0.5764,
#                                       'iabName': 'Hobbies & Interests',
#                                       'id': 1,
#                                       'instances': [{'adjustedEnd': '0:00:05.04',
#                                                      'adjustedStart': '0:00:00.56',
#                                                      'end': '0:00:05.04',
#                                                      'start': '0:00:00.56'}],
#                                       'iptcName': 'lifestyle and '
#                                                   'leisure/leisure/game/video '
#                                                   'game',
#                                       'language': 'en-US',
#                                       'name': 'Games',
#                                       'referenceId': 'Games and Gaming/Games',
#                                       'referenceType': 'VideoIndexer'}],
#                           'transcript': [{'confidence': 0.3418,
#                                           'id': 1,
#                                           'instances': [{'adjustedEnd': '0:00:05.04',
#                                                          'adjustedStart': '0:00:00.56',
#                                                          'end': '0:00:05.04',
#                                                          'start': '0:00:00.56'}],
#                                           'language': 'en-US',
#                                           'speakerId': 1,
#                                           'text': "If I'm not doing a lot, "
#                                                   "even when you don't know "
#                                                   'Tokyo.'}],
#                           'version': '1.0.0.0'},
#              'isAdult': False,
#              'isSearchable': True,
#              'language': 'en-US',
#              'languageAutoDetectMode': 'None',
#              'languages': ['en-US'],
#              'linguisticModelId': '00000000-0000-0000-0000-000000000000',
#              'logoGroupId': None,
#              'metadata': None,
#              'moderationState': 'OK',
#              'personModelId': '00000000-0000-0000-0000-000000000000',
#              'privacyMode': 'Private',
#              'processingProgress': '100%',
#              'publishedProxyUrl': None,
#              'publishedUrl': 'https://api.videoindexer.ai/internals/japaneast/Accounts/9a5f0740-eee6-4f8a-8022-f83961dc2f46/Videos/zsxqw62q07/streaming-manifest/manifest.m3u8',
#              'reviewState': 'None',
#              'sourceLanguage': 'en-US',
#              'sourceLanguages': ['en-US'],
#              'state': 'Processed',
#              'streamingPreset': 'Default',
#              'thumbnailId': '7cad8a68-fab1-4972-a4d6-1544c343e218',
#              'viewToken': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....rza87izn9IE0KWxFSDbh1I-LFE_dzLSrzvQeqLRtLfYw9gk8_ltSsO29jECgPHYCvPyRrZVg6MyJ51R1N9DT7U8ShLD8tp3o0wByGgjGwiMoTYL4cW4CbdlWUoqFttOnk8cCn_dm9jn1zOXArP4nVmjpeVM4kcaPWO29gg7aElWrw7zSrUlqykAOcgCk---toCJAJ2a9QBDAzxRmaPh6lezbYuVO7aNDaMw6sC7S97V4dCRk4XV2KkNDJsbFlEa8Bxt-JXmkSKHCVjK2Z2tJ7GzwZQPXSK1Y9aPX4zpzlx7_cHLup2jnXMBSWy9PLwyGMj4Dz2tLVIQavjVrubNfOw',
#              'width': 1392}],
#  'videosRanges': [{'range': {'end': '0:00:05.290646', 'start': '0:00:00'},
#                    'videoId': 'zsxqw62q07'}]}

# %% [markdown]
# #### Sample 5 - Widgets API

# %%
client.get_insights_widgets_url_async(video_id, widget_type='Keywords')
client.get_player_widget_url_async(video_id)
# Out:
# Getting the insights widget URL for video zsxqw62q07
# Got the insights widget URL: https://www.videoindexer.ai/embed/insights/9a5f0740-eee6-4f8a-8022-f83961dc2f46/zsxqw62q07/?location=japaneast&widgets=Keywords&accessToken=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....JAXLiaoPqvnZHduxajKA1kxdHNlQiAlN3u3zN2HFgaRiksZ3xFR94KhKxyPJy0pQQ4yqT0uztF0k1X5wD-X6JnHOXgEw2BgiNF5c2NQZZDnidqMUhGj6ZYLd4qR4RzV2WJ_0PLGNnz2C1Cnh1kaXY_Q6KsvNIj8X2bEcqCjAX0iFWrMeNg_jZRNlrF9RdoKmq3fVvsDHKLewDZWXn-9sqzhF9xhIreJwAEtVbnqqGukrl9EUhmnKdfEgACtSPxjt3DywIvudrahWVXmVI1NKTjk0Ly9A_nrnae0Z0IZ-nlXcGDXeEJWAhajs5Jvy-8CDl9amYpSELvsSr7Fo6SLqwA
# Getting the player widget URL for video zsxqw62q07
# Got the player widget URL: https://www.videoindexer.ai/embed/player/9a5f0740-eee6-4f8a-8022-f83961dc2f46/zsxqw62q07/?location=japaneast&accessToken=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....Wb9vroAKDfxmJ3f-mlLm67QTbztdQUen0BbvH2PTvKIjx-L8iiea83sJvwRkb5vSoxHbWKh3eXFk_N5RkCEMR-79AfMJJvN9oWCGqCaxwWAkp9HfwjWDAcLPeqJmCJLBZUqrL6Ugfb2LKAryEjt1Kcs3G0PSD_E3T6DXNuDz0vODUqwAUlP0JCf8nXzUvAXskmJ8mmaxAMGjIPOolThHqZXXCsVDc-dwHxpU8TqMuGkPqJBkqDHe5SqG2QbVXkmhcs2lGXVCxvuc3tSnBY2eFDzgsvngT8IDzZkzliclwweczMD71wN61yjBPdmqfvZJBQGfpC_UcRaCOE-MdL1VBA

# %% [markdown]
# #### Sample 6 - Prompt Content API

# %%
prompt_content = client.get_prompt_content(video_id)
pprint(prompt_content)
# Out:
# Prompt content generation for video_id='zsxqw62q07' started...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# {'name': 'video_short',
#  'partition': None,
#  'sections': [{'content': '[Video title] video_short\n'
#                           '[Detected objects] laptop\n'
#                           '[Visual labels] electronics, software\n'
#                           '[OCR] 3%, 97%, 13%, 33%, 23%, 12%, 前田 達志, '
#                           'データに関わる日本の現状とは?, 97%の日本企業はデータ活用で全社的に十分な成果を得ていない, '
#                           '全社的に十分な成果を得ている, 全社的にある程度の成果を得ている, わからない/したことがない, '
#                           '一部で十分な成果を得ている, 成果の評価は時期尚早·, まったく成果を得ていない, '
#                           '一部である程度の成果を得ている, ほとんど成果を得ていない, 出典:日本におけるデータ活用の実情| '
#                           'Gartner(2023年10月), n=400, FLYWHEEL Inc. All Rights '
#                           'Reserved., TECHPLAY 2024-07-18 - Go X, C2, zoom, '
#                           'Workplace, 前田 達志 さんの画面, サインイン, オーディオ設定 へ, チャット, '
#                           'リアクション, Q&A, 退出, 举手\n'
#                           "[Transcript] If I'm not doing a lot, even when you "
#                           "don't know Tokyo.",
#                'end': '0:00:05.281267',
#                'id': 0,
#                'start': '0:00:00.074167'}]}
